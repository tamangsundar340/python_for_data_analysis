# %% [markdown]
# ### Interacting with Web APIs

# %% [markdown]
# - __To find the last 30 GitHub issues for pandas on GitHub, we can make a GET HTTP request using the add-on requests library__

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'

resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %% [markdown]
# - __The Response object’s json method will return a dictionary containing JSON__

# %%
data = resp.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42458',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42458/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42458/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42458/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42458',
#   'id': 940607862,
#   'node_id': 'MDU6SXNzdWU5NDA2MDc4NjI=',
#   'number': 42458,
#   'title': 'BUG: `to_xml` raises `KeyError` for `index=False` when the index does not start at zero',
#   'user': {'login': 'stephan-hesselmann-by',
#    'id': 60873230,
#    'node_id': 'MDQ6VXNlcjYwODczMjMw',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60873230?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stephan-hesselmann-by',
#    'html_url': 'https://github.com/stephan-hesselmann-by',
#    'followers_url': 'https://api.github.com/users/stephan-hesselmann-by/followers',
#    'following_url': 'https://api.github.com/users/stephan-hesselmann-by/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stephan-hesselmann-by/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stephan-hesselmann-by/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stephan-hesselmann-by/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stephan-hesselmann-by/orgs',
#    'repos_url': 'https://api.github.com/users/stephan-hesselmann-by/repos',
#    'events_url': 'https://api.github.com/users/stephan-hesselmann-by/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stephan-hesselmann-by/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-07-09T09:52:38Z',
#   'updated_at': '2021-07-09T12:22:02Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [x] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport pandas as pd\r\n\r\nrecords = {"col1": [1, 2], "col2": [3, 4]}\r\ndf = pd.DataFrame(data=records)\r\n\r\ndf.index = range(1, 3)  # if this line is commented out it works as expected\r\nxml = df.to_xml(index=False)\r\nprint(xml)\r\n```\r\n\r\n#### Problem description\r\n\r\nThis code snipped should not raise a `KeyError`. The index should be ignored regardless of its content.\r\n\r\nTraceback:\r\n\r\n```\r\nTraceback (most recent call last):\r\n  File "/Users/xxx/xml.py", line 7, in <module>\r\n    xml = df.to_xml(index=False)\r\n  File "/Users/xxx/pandas/core/frame.py", line 2967, in to_xml\r\n    xml_formatter = TreeBuilder(\r\n  File "/Users/xxx/pandas/io/formats/xml.py", line 458, in __init__\r\n    self.handle_indexes()\r\n  File "/Users/xxx/pandas/io/formats/xml.py", line 199, in handle_indexes\r\n    x for x in self.frame_dicts[0].keys() if x not in self.orig_cols\r\nKeyError: 0\r\n```\r\n\r\n#### Expected Output\r\n\r\n```xml\r\n<?xml version=\'1.0\' encoding=\'utf-8\'?>\r\n<data>\r\n  <row>\r\n    <col1>1</col1>\r\n    <col2>3</col2>\r\n  </row>\r\n  <row>\r\n    <col1>2</col1>\r\n    <col2>4</col2>\r\n  </row>\r\n</data>\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f00ed8f47020034e752baf0250483053340971b0\r\npython           : 3.9.6.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.5.0\r\nVersion          : Darwin Kernel Version 20.5.0: Sat May  8 05:10:33 PDT 2021; root:xnu-7195.121.3~9/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : en_US.UTF-8\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.3.0\r\nnumpy            : 1.21.0\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.3\r\nsetuptools       : None\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : None\r\nsphinx           : 4.0.3\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.6.3\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.9.3\r\nbottleneck       : None\r\nfsspec           : 2021.06.1\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.2\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 4.0.1\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsqlalchemy       : 1.4.15\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\nNone\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42456',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42456/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42456/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42456/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42456',
#   'id': 940475397,
#   'node_id': 'MDU6SXNzdWU5NDA0NzUzOTc=',
#   'number': 42456,
#   'title': 'BUG: Regression on DataFrame.from_records',
#   'user': {'login': 'felixdivo',
#    'id': 4403130,
#    'node_id': 'MDQ6VXNlcjQ0MDMxMzA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4403130?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/felixdivo',
#    'html_url': 'https://github.com/felixdivo',
#    'followers_url': 'https://api.github.com/users/felixdivo/followers',
#    'following_url': 'https://api.github.com/users/felixdivo/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/felixdivo/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/felixdivo/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/felixdivo/subscriptions',
#    'organizations_url': 'https://api.github.com/users/felixdivo/orgs',
#    'repos_url': 'https://api.github.com/users/felixdivo/repos',
#    'events_url': 'https://api.github.com/users/felixdivo/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/felixdivo/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-07-09T06:54:18Z',
#   'updated_at': '2021-07-09T06:54:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nfrom numpy import empty, array\r\nfrom pandas import DataFrame\r\n\r\nstructured_dtype = [('prop', int)]\r\n\r\n# Does NOT work any more\r\nresult = empty((0, len(structured_dtype)))\r\nstructured_array = array(result, dtype=structured_dtype)\r\nDataFrame.from_records(structured_array)\r\n```\r\n\r\nTriggers: `ValueError: If using all scalar values, you must pass an index`.\r\n\r\n#### Problem description\r\n\r\nThis previously worked on Pandas version 1.2.5.\r\n\r\n#### Expected Output\r\n\r\nNo exception.\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f00ed8f47020034e752baf0250483053340971b0\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-77-generic\r\nVersion          : #86-Ubuntu SMP Thu Jun 17 02:35:03 UTC 2021\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\npandas           : 1.3.0\r\nnumpy            : 1.21.0\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 20.0.2\r\nsetuptools       : 57.0.0\r\nCython           : None\r\npytest           : 6.2.4\r\nhypothesis       : 6.14.0\r\nsphinx           : 4.0.2\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 3.0.1\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.4.2\r\nnumexpr          : 2.7.3\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.7.0\r\nsqlalchemy       : None\r\ntables           : 3.6.1\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42455',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42455/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42455/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42455/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42455',
#   'id': 940461381,
#   'node_id': 'MDU6SXNzdWU5NDA0NjEzODE=',
#   'number': 42455,
#   'title': 'BUG: Pandas `string` dtype reverts to `object` dtype when initialising index',
#   'user': {'login': 'mlee94',
#    'id': 48900197,
#    'node_id': 'MDQ6VXNlcjQ4OTAwMTk3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48900197?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mlee94',
#    'html_url': 'https://github.com/mlee94',
#    'followers_url': 'https://api.github.com/users/mlee94/followers',
#    'following_url': 'https://api.github.com/users/mlee94/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mlee94/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mlee94/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mlee94/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mlee94/orgs',
#    'repos_url': 'https://api.github.com/users/mlee94/repos',
#    'events_url': 'https://api.github.com/users/mlee94/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mlee94/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-07-09T06:29:25Z',
#   'updated_at': '2021-07-09T06:29:31Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x]  I have checked that this issue has not already been reported.\r\n\r\n- [x]  I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ]  (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n1.\r\n```\r\nIn [2]: pd.Index(['A', 'B', 'C', 'D'], dtype=pd.StringDtype()).dtype\r\nOut[2]: dtype('O')\r\n\r\nIn [3]: pd.Index([1, 2, 3, 4], dtype=int).dtype\r\nOut[3]: dtype('int64')\r\n```\r\n2.\r\n<details>\r\n  <summary>Output pd.show_versions()</summary>\r\n\r\n\r\n```\r\n  INSTALLED VERSIONS\r\n  ------------------\r\n  commit           : f00ed8f47020034e752baf0250483053340971b0\r\n  python           : 3.7.9.final.0\r\n  python-bits      : 64\r\n  OS               : Windows\r\n  OS-release       : 10\r\n  Version          : 10.0.19041\r\n  machine          : AMD64\r\n  processor        : Intel64 Family 6 Model 58 Stepping 0, GenuineIntel\r\n  byteorder        : little\r\n  LC_ALL           : None\r\n  LANG             : None\r\n  LOCALE           : None.None\r\n  \r\n  pandas           : 1.3.0\r\n  numpy            : 1.19.5\r\n  pytz             : 2020.5\r\n  dateutil         : 2.8.1\r\n  pip              : 21.0\r\n  setuptools       : 49.6.0.post20210108\r\n  Cython           : None\r\n  pytest           : 6.2.1\r\n  hypothesis       : None\r\n  sphinx           : 3.5.4\r\n  blosc            : None\r\n  feather          : None\r\n  xlsxwriter       : 1.3.9\r\n  lxml.etree       : 4.6.3\r\n  html5lib         : None\r\n  pymysql          : None\r\n  psycopg2         : 2.8.6 (dt dec pq3 ext lo64)\r\n  jinja2           : 2.11.2\r\n  IPython          : 7.19.0\r\n  pandas_datareader: None\r\n  bs4              : 4.9.3\r\n  bottleneck       : None\r\n  fsspec           : 2021.05.0\r\n  fastparquet      : None\r\n  gcsfs            : None\r\n  matplotlib       : 3.3.3\r\n  numexpr          : None\r\n  odfpy            : None\r\n  openpyxl         : 3.0.7\r\n  pandas_gbq       : None\r\n  pyarrow          : 3.0.0\r\n  pyxlsb           : None\r\n  s3fs             : None\r\n  scipy            : 1.6.2\r\n  sqlalchemy       : 1.4.3\r\n  tables           : None\r\n  tabulate         : 0.8.9\r\n  xarray           : 0.16.2\r\n  xlrd             : None\r\n  xlwt             : None\r\n  numba            : 0.53.1\r\n```\r\n\r\n</details>\r\n\r\n\r\n3.\r\nI don't think the dtype should change here. Seems to be okay for other dtypes apart from strings.",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42452',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42452/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42452/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42452/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42452',
#   'id': 940316394,
#   'node_id': 'MDU6SXNzdWU5NDAzMTYzOTQ=',
#   'number': 42452,
#   'title': 'BUG: pandas EWM fails silently if data types are float32 instead of float64',
#   'user': {'login': 'PCerles',
#    'id': 3850216,
#    'node_id': 'MDQ6VXNlcjM4NTAyMTY=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3850216?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/PCerles',
#    'html_url': 'https://github.com/PCerles',
#    'followers_url': 'https://api.github.com/users/PCerles/followers',
#    'following_url': 'https://api.github.com/users/PCerles/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/PCerles/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/PCerles/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/PCerles/subscriptions',
#    'organizations_url': 'https://api.github.com/users/PCerles/orgs',
#    'repos_url': 'https://api.github.com/users/PCerles/repos',
#    'events_url': 'https://api.github.com/users/PCerles/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/PCerles/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 1045950827,
#     'node_id': 'MDU6TGFiZWwxMDQ1OTUwODI3',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Window',
#     'name': 'Window',
#     'color': 'd4c5f9',
#     'default': False,
#     'description': 'rolling, ewma, expanding'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1084,
#    'closed_issues': 740,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-07-09T04:33:21Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-07-09T00:33:20Z',
#   'updated_at': '2021-07-09T04:33:21Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [X ] I have checked that this issue has not already been reported.\r\n\r\n- [ X] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\n\r\nkk = pd.DataFrame(np.random.rand(20, 3))\r\nkk = kk.astype(np.float32)\r\nprint(kk.ewm(alpha=0.5, axis=1).mean().shape)\r\n# (20, 0)\r\n\r\nkk = kk.astype(np.float64)\r\nprint(kk.ewm(alpha=0.5, axis=1).mean().shape)\r\n\r\n# (20, 3)\r\n```\r\n\r\n#### Problem description\r\n\r\nThis should not depend on dtypes.\r\n\r\n#### Expected Output\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\ncommit           : 7c48ff4409c622c582c56a5702373f726de08e96\r\npython           : 3.7.10.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.5.0\r\nVersion          : Darwin Kernel Version 20.5.0: Sat May  8 05:10:33 PDT 2021; root:xnu-7195.121.3~9/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.2.5\r\nnumpy            : 1.17.4\r\npytz             : 2020.1\r\ndateutil         : 2.8.1\r\npip              : 21.1.2\r\nsetuptools       : 57.0.0\r\nCython           : None\r\npytest           : 6.2.2\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.8.5 (dt dec pq3 ext lo64)\r\njinja2           : 2.10.3\r\nIPython          : 7.23.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : 0.4.1\r\ngcsfs            : None\r\nmatplotlib       : 3.3.4\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : 3.0.6\r\npandas_gbq       : None\r\npyarrow          : 0.17.1\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.5.4\r\nsqlalchemy       : 1.3.19\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : 1.2.0\r\nxlwt             : None\r\nnumba            : 0.53.1\r\n\r\n</details>\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42451',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42451/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42451/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42451/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42451',
#   'id': 940133422,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njg2MjUwNTg4',
#   'number': 42451,
#   'title': 'CI: Sync all 3.9 builds',
#   'user': {'login': 'lithomas1',
#    'id': 47963215,
#    'node_id': 'MDQ6VXNlcjQ3OTYzMjE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47963215?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lithomas1',
#    'html_url': 'https://github.com/lithomas1',
#    'followers_url': 'https://api.github.com/users/lithomas1/followers',
#    'following_url': 'https://api.github.com/users/lithomas1/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lithomas1/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lithomas1/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lithomas1/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lithomas1/orgs',
#    'repos_url': 'https://api.github.com/users/lithomas1/repos',
#    'events_url': 'https://api.github.com/users/lithomas1/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lithomas1/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 48070600,
#     'node_id': 'MDU6TGFiZWw0ODA3MDYwMA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/CI',
#     'name': 'CI',
#     'color': 'a2bca7',
#     'default': False,
#     'description': 'Related to Continuous Integration'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/87',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87/labels',
#    'id': 6888188,
#    'node_id': 'MDk6TWlsZXN0b25lNjg4ODE4OA==',
#    'number': 87,
#    'title': '1.3.1',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 21,
#    'closed_issues': 27,
#    'state': 'open',
#    'created_at': '2021-06-25T09:56:22Z',
#    'updated_at': '2021-07-09T03:34:14Z',
#    'due_on': '2021-07-25T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-07-08T18:54:12Z',
#   'updated_at': '2021-07-08T19:34:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42451',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42451',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42451.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42451.patch'},
#   'body': '- [x] closes #37826\r\n\r\nIIUC, all the 3.9 builds(except numpydev) should have all dependencies.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42450',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42450/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42450/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42450/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42450',
#   'id': 940122978,
#   'node_id': 'MDU6SXNzdWU5NDAxMjI5Nzg=',
#   'number': 42450,
#   'title': 'BUG: unstack after loc produces unexpected index order',
#   'user': {'login': 'snovaisg',
#    'id': 24900912,
#    'node_id': 'MDQ6VXNlcjI0OTAwOTEy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24900912?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/snovaisg',
#    'html_url': 'https://github.com/snovaisg',
#    'followers_url': 'https://api.github.com/users/snovaisg/followers',
#    'following_url': 'https://api.github.com/users/snovaisg/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/snovaisg/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/snovaisg/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/snovaisg/subscriptions',
#    'organizations_url': 'https://api.github.com/users/snovaisg/orgs',
#    'repos_url': 'https://api.github.com/users/snovaisg/repos',
#    'events_url': 'https://api.github.com/users/snovaisg/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/snovaisg/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-07-08T18:38:04Z',
#   'updated_at': '2021-07-08T20:26:24Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nidx = pd.IndexSlice\r\n\r\ndf = pd.DataFrame({'x':[1,2,3], \r\n                   'y':['a','b','c'],\r\n                   'z':['a*','b*','c*']\r\n                 }).set_index(['y','z'])\r\n\r\nnew_y_order = ['c', 'b', 'a']\r\nnew_df = df.loc[idx[new_y_order,:],:].unstack('z') # <- this produces the unexpected behaviour.\r\nprint(new_df)\r\n#      x               \r\n# z   a*   b*   c*\r\n# y                    \r\n# a  1.0  NaN  NaN\r\n# b  NaN  2.0  NaN\r\n# c  NaN  NaN  3.0\r\n\r\n```\r\n\r\n#### Problem description\r\n\r\nChanging the order of `df`'s index using `loc` and calling `unstack` on the 2º index level, results in a dataframe whose index order unexpectedly remains the same as the initial index. However, the new index' order should follow `new_y_order`.\r\n\r\nAdditional notes:\r\n- This behaviour happens only when all index elements are preserved when changing their order. In other words, If `new_y_order` contains fewer elements than `y`, then calling unstack would behave as expected.\r\n- This unexpected behaviour happens even if we store the `.loc` reordering using `.copy()`, before applying `.unstack`. The DataFrame somehow remembers the initial index order it had.\r\n\r\n#### Expected Output\r\n```python\r\nprint(new_df)\r\n#      x          \r\n# z   c*   b*   a*\r\n# y               \r\n# c  3.0  NaN  NaN\r\n# b  NaN  2.0  NaN\r\n# a  NaN  NaN  1.0\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f00ed8f47020034e752baf0250483053340971b0\r\npython           : 3.8.1.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 20.2.0\r\nVersion          : Darwin Kernel Version 20.2.0: Wed Dec  2 20:39:59 PST 2020; root:xnu-7195.60.75~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : None.UTF-8\r\n\r\npandas           : 1.3.0\r\nnumpy            : 1.19.2\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 21.0.1\r\nsetuptools       : 52.0.0.post20210125\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.3\r\nIPython          : 7.21.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : None\r\ngcsfs            : None\r\nmatplotlib       : 3.3.2\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.1\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : 0.8.9\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : None\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42449',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42449/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42449/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42449/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42449',
#   'id': 940107534,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njg2MjI4MzM2',
#   'number': 42449,
#   'title': 'REGR: DataFrame.agg with axis=1, EA dtype, and duplicate index',
#   'user': {'login': 'rhshadrach',
#    'id': 45562402,
#    'node_id': 'MDQ6VXNlcjQ1NTYyNDAy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/45562402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rhshadrach',
#    'html_url': 'https://github.com/rhshadrach',
#    'followers_url': 'https://api.github.com/users/rhshadrach/followers',
#    'following_url': 'https://api.github.com/users/rhshadrach/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rhshadrach/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rhshadrach/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rhshadrach/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rhshadrach/orgs',
#    'repos_url': 'https://api.github.com/users/rhshadrach/repos',
#    'events_url': 'https://api.github.com/users/rhshadrach/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rhshadrach/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'},
#    {'id': 13098779,
#     'node_id': 'MDU6TGFiZWwxMzA5ODc3OQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Reshaping',
#     'name': 'Reshaping',
#     'color': '02d7e1',
#     'default': False,
#     'description': 'Concat, Merge/Join, Stack/Unstack'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/87',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87/labels',
#    'id': 6888188,
#    'node_id': 'MDk6TWlsZXN0b25lNjg4ODE4OA==',
#    'number': 87,
#    'title': '1.3.1',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 21,
#    'closed_issues': 27,
#    'state': 'open',
#    'created_at': '2021-06-25T09:56:22Z',
#    'updated_at': '2021-07-09T03:34:14Z',
#    'due_on': '2021-07-25T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2021-07-08T18:16:08Z',
#   'updated_at': '2021-07-08T19:51:17Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42449',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42449',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42449.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42449.patch'},
#   'body': '- [x] closes #42380\r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n\r\nThe issue in transpose was a bug that was introduced in 1.0.0, but induced a regression in 1.3.0 due to its use in `DataFrame.agg`.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42448',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42448/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42448/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42448/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/42448',
#   'id': 939925123,
#   'node_id': 'MDExOlB1bGxSZXF1ZXN0Njg2MDcyMjY1',
#   'number': 42448,
#   'title': 'BUG: Issue with pd.cut on Series with duplicate index',
#   'user': {'login': 'debnathshoham',
#    'id': 6472290,
#    'node_id': 'MDQ6VXNlcjY0NzIyOTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6472290?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/debnathshoham',
#    'html_url': 'https://github.com/debnathshoham',
#    'followers_url': 'https://api.github.com/users/debnathshoham/followers',
#    'following_url': 'https://api.github.com/users/debnathshoham/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/debnathshoham/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/debnathshoham/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/debnathshoham/subscriptions',
#    'organizations_url': 'https://api.github.com/users/debnathshoham/orgs',
#    'repos_url': 'https://api.github.com/users/debnathshoham/repos',
#    'events_url': 'https://api.github.com/users/debnathshoham/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/debnathshoham/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2021-07-08T14:33:11Z',
#   'updated_at': '2021-07-08T14:33:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/42448',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/42448',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/42448.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/42448.patch'},
#   'body': '- [x] closes #42185 \r\n- [x] tests added / passed\r\n- [x] Ensure all linting tests pass, see [here](https://pandas.pydata.org/pandas-docs/dev/development/contributing.html#code-standards) for how to run them\r\n- [x] whatsnew entry\r\n\r\nCreating a new PR. I had messed up the earlier one by mistake.',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42446',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42446/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42446/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42446/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42446',
#   'id': 939887645,
#   'node_id': 'MDU6SXNzdWU5Mzk4ODc2NDU=',
#   'number': 42446,
#   'title': 'option dtype in pandas.read_csv does not work properly for mulilevel columns',
#   'user': {'login': 'jottbele',
#    'id': 52567084,
#    'node_id': 'MDQ6VXNlcjUyNTY3MDg0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52567084?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jottbele',
#    'html_url': 'https://github.com/jottbele',
#    'followers_url': 'https://api.github.com/users/jottbele/followers',
#    'following_url': 'https://api.github.com/users/jottbele/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jottbele/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jottbele/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jottbele/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jottbele/orgs',
#    'repos_url': 'https://api.github.com/users/jottbele/repos',
#    'events_url': 'https://api.github.com/users/jottbele/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jottbele/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/32',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/32/labels',
#    'id': 933188,
#    'node_id': 'MDk6TWlsZXN0b25lOTMzMTg4',
#    'number': 32,
#    'title': 'Contributions Welcome',
#    'description': 'Changes that would be nice to have in the next release. These issues are not blocking. They will be pushed to the next release if no one has time to fix them.',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 1084,
#    'closed_issues': 740,
#    'state': 'open',
#    'created_at': '2015-01-13T10:53:19Z',
#    'updated_at': '2021-07-09T04:33:21Z',
#    'due_on': None,
#    'closed_at': None},
#   'comments': 4,
#   'created_at': '2021-07-08T13:55:35Z',
#   'updated_at': '2021-07-08T15:43:48Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
# ...
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42399',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42399/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42399/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42399/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42399',
#   'id': 937763466,
#   'node_id': 'MDU6SXNzdWU5Mzc3NjM0NjY=',
#   'number': 42399,
#   'title': 'BUG: setting start argument in offsets.BusinessHour produces wrong start time for each second day.',
#   'user': {'login': 'erfannariman',
#    'id': 34067903,
#    'node_id': 'MDQ6VXNlcjM0MDY3OTAz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/34067903?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/erfannariman',
#    'html_url': 'https://github.com/erfannariman',
#    'followers_url': 'https://api.github.com/users/erfannariman/followers',
#    'following_url': 'https://api.github.com/users/erfannariman/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/erfannariman/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/erfannariman/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/erfannariman/subscriptions',
#    'organizations_url': 'https://api.github.com/users/erfannariman/orgs',
#    'repos_url': 'https://api.github.com/users/erfannariman/repos',
#    'events_url': 'https://api.github.com/users/erfannariman/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/erfannariman/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2021-07-06T10:46:17Z',
#   'updated_at': '2021-07-06T21:50:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [x] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nstart = pd.Timestamp(\'2021-07-05 08:10:11\')\r\nend = pd.Timestamp(\'2021-07-07 12:13:14\')\r\n\r\ndates = pd.date_range(start, end, freq=pd.offsets.BusinessHour(start="08:30"))\r\nprint(dates)\r\n\r\nDatetimeIndex([\'2021-07-05 08:30:00\', \'2021-07-05 09:30:00\',\r\n               \'2021-07-05 10:30:00\', \'2021-07-05 11:30:00\',\r\n               \'2021-07-05 12:30:00\', \'2021-07-05 13:30:00\',\r\n               \'2021-07-05 14:30:00\', \'2021-07-05 15:30:00\',\r\n               \'2021-07-05 16:30:00\', \'2021-07-06 09:00:00\',\r\n               \'2021-07-06 10:00:00\', \'2021-07-06 11:00:00\',\r\n               \'2021-07-06 12:00:00\', \'2021-07-06 13:00:00\',\r\n               \'2021-07-06 14:00:00\', \'2021-07-06 15:00:00\',\r\n               \'2021-07-06 16:00:00\', \'2021-07-07 08:30:00\',\r\n               \'2021-07-07 09:30:00\', \'2021-07-07 10:30:00\',\r\n               \'2021-07-07 11:30:00\'],\r\n              dtype=\'datetime64[ns]\', freq=\'BH\')\r\n\r\n\r\ndates.to_series().groupby(dates.date).min()\r\n\r\n2021-07-05   2021-07-05 08:30:00\r\n2021-07-06   2021-07-06 09:00:00\r\n2021-07-07   2021-07-07 08:30:00\r\ndtype: datetime64[ns]\r\n```\r\n\r\n#### Problem description\r\n\r\nMaking use the `start` argument in offsets.BusinessHour produces the wrong start time for each second day. So in the example above, I would\'ve expected `2021-07-06` to start on `08:30:00`  instead of `09:00:00`\r\n\r\n#### Expected Output\r\n\r\nSee the description above.\r\n\r\npandas version 1.3.0.\r\n',
#   'performed_via_github_app': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42396',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42396/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42396/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/42396/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/42396',
#   'id': 937702381,
#   'node_id': 'MDU6SXNzdWU5Mzc3MDIzODE=',
#   'number': 42396,
#   'title': 'BUG: astype() on an integer DataFrame changes the order of data',
#   'user': {'login': 'wjsi',
#    'id': 8284922,
#    'node_id': 'MDQ6VXNlcjgyODQ5MjI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8284922?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/wjsi',
#    'html_url': 'https://github.com/wjsi',
#    'followers_url': 'https://api.github.com/users/wjsi/followers',
#    'following_url': 'https://api.github.com/users/wjsi/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/wjsi/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/wjsi/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/wjsi/subscriptions',
#    'organizations_url': 'https://api.github.com/users/wjsi/orgs',
#    'repos_url': 'https://api.github.com/users/wjsi/repos',
#    'events_url': 'https://api.github.com/users/wjsi/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/wjsi/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtypes',
#     'name': 'Dtypes',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'},
#    {'id': 32815646,
#     'node_id': 'MDU6TGFiZWwzMjgxNTY0Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Regression',
#     'name': 'Regression',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Functionality that used to work in a prior pandas version'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': {'login': 'debnathshoham',
#    'id': 6472290,
#    'node_id': 'MDQ6VXNlcjY0NzIyOTA=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6472290?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/debnathshoham',
#    'html_url': 'https://github.com/debnathshoham',
#    'followers_url': 'https://api.github.com/users/debnathshoham/followers',
#    'following_url': 'https://api.github.com/users/debnathshoham/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/debnathshoham/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/debnathshoham/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/debnathshoham/subscriptions',
#    'organizations_url': 'https://api.github.com/users/debnathshoham/orgs',
#    'repos_url': 'https://api.github.com/users/debnathshoham/repos',
#    'events_url': 'https://api.github.com/users/debnathshoham/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/debnathshoham/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'assignees': [{'login': 'debnathshoham',
#     'id': 6472290,
#     'node_id': 'MDQ6VXNlcjY0NzIyOTA=',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/6472290?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/debnathshoham',
#     'html_url': 'https://github.com/debnathshoham',
#     'followers_url': 'https://api.github.com/users/debnathshoham/followers',
#     'following_url': 'https://api.github.com/users/debnathshoham/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/debnathshoham/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/debnathshoham/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/debnathshoham/subscriptions',
#     'organizations_url': 'https://api.github.com/users/debnathshoham/orgs',
#     'repos_url': 'https://api.github.com/users/debnathshoham/repos',
#     'events_url': 'https://api.github.com/users/debnathshoham/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/debnathshoham/received_events',
#     'type': 'User',
#     'site_admin': False}],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/87',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/87/labels',
#    'id': 6888188,
#    'node_id': 'MDk6TWlsZXN0b25lNjg4ODE4OA==',
#    'number': 87,
#    'title': '1.3.1',
#    'description': 'on-merge: backport to 1.3.x',
#    'creator': {'login': 'simonjayhawkins',
#     'id': 13159005,
#     'node_id': 'MDQ6VXNlcjEzMTU5MDA1',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/13159005?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/simonjayhawkins',
#     'html_url': 'https://github.com/simonjayhawkins',
#     'followers_url': 'https://api.github.com/users/simonjayhawkins/followers',
#     'following_url': 'https://api.github.com/users/simonjayhawkins/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/simonjayhawkins/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/simonjayhawkins/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/simonjayhawkins/subscriptions',
#     'organizations_url': 'https://api.github.com/users/simonjayhawkins/orgs',
#     'repos_url': 'https://api.github.com/users/simonjayhawkins/repos',
#     'events_url': 'https://api.github.com/users/simonjayhawkins/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/simonjayhawkins/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 21,
#    'closed_issues': 27,
#    'state': 'open',
#    'created_at': '2021-06-25T09:56:22Z',
#    'updated_at': '2021-07-09T03:34:14Z',
#    'due_on': '2021-07-25T07:00:00Z',
#    'closed_at': None},
#   'comments': 3,
#   'created_at': '2021-07-06T09:31:51Z',
#   'updated_at': '2021-07-09T10:06:59Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': "- [x] I have checked that this issue has not already been reported.\r\n\r\n- [x] I have confirmed this bug exists on the latest version of pandas.\r\n\r\n- [ ] (optional) I have confirmed this bug exists on the master branch of pandas.\r\n\r\n---\r\n\r\n**Note**: Please read [this guide](https://matthewrocklin.com/blog/work/2018/02/28/minimal-bug-reports) detailing how to provide the necessary information for us to reproduce your bug.\r\n\r\n#### Code Sample, a copy-pastable example\r\n\r\n```python\r\nimport numpy as np\r\nimport pandas as pd\r\nnpa = np.random.RandomState(0).randint(1000, size=(20, 8))\r\ndf = pd.DataFrame(npa, columns=[f'c{i}' for i in range(8)])\r\nprint(df.iloc[:6, :3])\r\n#     c0   c1   c2\r\n# 0  684  559  629\r\n# 1    9  723  277\r\n# 2  600  396  314\r\n# 3  600  849  677\r\n# 4  115  976  755\r\n# 5   99  984  177\r\nprint(df.iloc[:6, :3].astype('int32'))\r\n#     c0   c1   c2\r\n# 0  684  600  115\r\n# 1  559  396  976\r\n# 2  629  314  755\r\n# 3    9  600   99\r\n# 4  723  849  984\r\n# 5  277  677  177\r\n```\r\n\r\n#### Problem description\r\n\r\nThe order of output result is changed unexpectedly after `astype` is called. It may caused by data continuity as `df.iloc[:6, :3].copy().astype('int32')` works as expected.\r\n\r\n#### Expected Output\r\n\r\n```python\r\nprint(df.iloc[:6, :3].astype('int32'))\r\n#     c0   c1   c2\r\n# 0  684  559  629\r\n# 1    9  723  277\r\n# 2  600  396  314\r\n# 3  600  849  677\r\n# 4  115  976  755\r\n# 5   99  984  177\r\n```\r\n\r\n#### Output of ``pd.show_versions()``\r\n\r\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : f00ed8f47020034e752baf0250483053340971b0\r\npython           : 3.8.5.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 19.6.0\r\nVersion          : Darwin Kernel Version 19.6.0: Thu May  6 00:48:39 PDT 2021; root:xnu-6153.141.33~1/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : zh_CN.UTF-8\r\npandas           : 1.3.0\r\nnumpy            : 1.18.5\r\npytz             : 2021.1\r\ndateutil         : 2.8.1\r\npip              : 20.2.2\r\nsetuptools       : 49.6.0.post20200814\r\nCython           : 0.29.23\r\npytest           : 6.2.2\r\nhypothesis       : 6.3.0\r\nsphinx           : 3.2.1\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : 2.11.2\r\nIPython          : 7.17.0\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nfsspec           : None\r\nfastparquet      : 0.4.2\r\ngcsfs            : None\r\nmatplotlib       : 3.2.2\r\nnumexpr          : 2.7.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 4.0.0\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.6.0\r\nsqlalchemy       : 1.3.18\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nnumba            : 0.53.0\r\n\r\n</details>\r\n",
#   'performed_via_github_app': None}]

# %%
# now fetch data
data[0]['title']
# Out:
# 'BUG: `to_xml` raises `KeyError` for `index=False` when the index does not start at zero'

# %% [markdown]
# - __We can pass data directly to DataFrame and extract fields of interest__

# %%
import pandas as pd

issues = pd.DataFrame(data, columns=['user','title','labels'])
issues[:10]
# Out:
#                                                 user  \
# 0  {'login': 'stephan-hesselmann-by', 'id': 60873...
# 1  {'login': 'felixdivo', 'id': 4403130, 'node_id...
# 2  {'login': 'mlee94', 'id': 48900197, 'node_id':...
# 3  {'login': 'PCerles', 'id': 3850216, 'node_id':...
# 4  {'login': 'lithomas1', 'id': 47963215, 'node_i...
# 5  {'login': 'snovaisg', 'id': 24900912, 'node_id...
# 6  {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 7  {'login': 'debnathshoham', 'id': 6472290, 'nod...
# 8  {'login': 'jottbele', 'id': 52567084, 'node_id...
# 9  {'login': 'sunpei-zju', 'id': 26964756, 'node_...
#
#                                                title  \
# 0  BUG: `to_xml` raises `KeyError` for `index=Fal...
# 1          BUG: Regression on DataFrame.from_records
# 2  BUG: Pandas `string` dtype reverts to `object`...
# 3  BUG: pandas EWM fails silently if data types a...
# 4                            CI: Sync all 3.9 builds
# 5  BUG: unstack after loc produces unexpected ind...
# 6  REGR: DataFrame.agg with axis=1, EA dtype, and...
# 7  BUG: Issue with pd.cut on Series with duplicat...
# 8  option dtype in pandas.read_csv does not work ...
# 9                        BUG: NaN cannot be detected
#
#                                               labels
# 0  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 1  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 2                                                 []
# 3  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 4  [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...
# 5  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 6  [{'id': 697792067, 'node_id': 'MDU6TGFiZWw2OTc...
# 7                                                 []
# 8  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...
# 9  [{'id': 2628846204, 'node_id': 'MDU6TGFiZWwyNj...

# %% [markdown]
# ### Interacting with Databases

# %% [markdown]
# - __Create a SQLite database using Python’s built-in sqlite3 driver:__

# %%
import sqlite3

# %%
query = """ 
create table test(
a varvhar(20),
b varchar(20),
c Real,
d Integer
);
"""

# %% [markdown]
# - __'mydata.sqlite' will be sqlite3 file name__

# %%
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %% [markdown]
# - __Insert data into database__

# %%
data = [
    ('aa','bb', 1.25, 6),
    ('cc','dd', 1.50, 7),
    ('ee','ff', 1.75, 8)
]

stmt = "INSERT INTO test VALUES(?,?,?,?)"
con.executemany(stmt, data)
con.commit()

# %% [markdown]
# - __select data__

# %%
cursor = con.execute('select *from test')
rows = cursor.fetchall()
rows
# Out:
# [('aa', 'bb', 1.25, 6), ('cc', 'dd', 1.5, 7), ('ee', 'ff', 1.75, 8)]

# %%
cursor.description
